# %%
# %load_ext autoreload
# %autoreload 2
from utilsTokenComparison import *
from utilsTransformer import *
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ##### The datatset download links (German, English) in the original Harvard NLP code*  no longer work; replace download links.
#
# *https://github.com/harvardnlp/annotated-transformer

# %%
from torchtext.datasets import multi30k
#
multi30k.URL["train"] = "https://raw.githubusercontent.com/neychev/small_DL_repo/master/datasets/Multi30k/training.tar.gz"
multi30k.URL["valid"] = "https://raw.githubusercontent.com/neychev/small_DL_repo/master/datasets/Multi30k/validation.tar.gz"
multi30k.URL["test"] = "https://raw.githubusercontent.com/neychev/small_DL_repo/master/datasets/Multi30k/mmt16_task1_test.tar.gz"
###
multi30k.MD5["train"] = "20140d013d05dd9a72dfde46478663ba05737ce983f478f960c1123c6671be5e"
multi30k.MD5["valid"] = "a7aa20e9ebd5ba5adce7909498b94410996040857154dab029851af3a866da8c"
multi30k.MD5["test"] = "6d1ca1dba99e2c5dd54cae1226ff11c2551e6ce63527ebb072a1f70f72a5cd36"

# %% [markdown]
# ### Load BERT tokenizer, BERT vocabulary and trained BERT model

# %%
from transformers import  AutoTokenizer
tknzrBert = AutoTokenizer.from_pretrained("bert-base-multilingual-cased")
vocabBertDe, vocabBertEng = torch.load("vocab_%s.pt" %"Bert")
print(f"Length of Bert German Vocabulary = {len(vocabBertDe)}")
print(f"Length of Bert English Vocabulary = {len(vocabBertEng)}")
modelBert = make_model(len(vocabBertDe), len(vocabBertEng), N=6)
model_path = "multi30k_model_%s_final.pt" %"bert"
modelBert.load_state_dict(torch.load(model_path, map_location= device))
# Out:
# Length of Bert German Vocabulary = 8804
# Length of Bert English Vocabulary = 8076
# <All keys matched successfully>

# %% [markdown]
# ### Load GPT tokenizer, GPT vocabulary, and trained GPT model

# %%
from transformers import  AutoTokenizer
tknzrGpt = AutoTokenizer.from_pretrained("openai-community/openai-gpt")
vocabGptDe, vocabGptEng = torch.load("vocab_%s.pt" %"gpt")
print(f"Length of GPT German Vocabulary = {len(vocabGptDe)}")
print(f"Length of GPT English Vocabulary = {len(vocabGptEng)}")
modelGpt = make_model(len(vocabGptDe), len(vocabGptEng), N=6)
model_path = "multi30k_model_%s_final.pt" %"gpt"
modelGpt.load_state_dict(torch.load(model_path, map_location= device))
# Out:
# Length of GPT German Vocabulary = 4218
# Length of GPT English Vocabulary = 9570
# <All keys matched successfully>

# %%
def check_outputs(
    valid_dataloader,
    modelBert,
    vocabBertDe,
    vocabBertEng,#
    modelGpt,
    vocabGptDe,
    vocabGptEng,
    n_examples=15,
    pad_idx=2,
    eos_string="</s>"
):
    for idx in range(n_examples):
        print("\nExample %d ========\n" % idx)
        b = next(iter(valid_dataloader))
        ###
        # BERT MODEL
        ###
        rb = Batch(b[0], b[1], pad_idx) # change the collate function for valid_dataloader to return b[0],b[1],b[2],b[3]
                                        # b[2],b[3] are the source and target tok2Id for HF model
        src_tokens = [
            vocabBertDe.get_itos()[x] for x in rb.src[0] if x != pad_idx
        ]
        tgt_tokens = [
            vocabBertEng.get_itos()[x] for x in rb.tgt[0] if x != pad_idx
        ]
        print(
            "Source Bert Text (Input)        : "
            + " ".join(src_tokens).replace("\n", "")
        )
        print(
            "Target Bert Text (Ground Truth) : "
            + " ".join(tgt_tokens).replace("\n", "")
        )
        model_out = greedy_decode(modelBert, rb.src, rb.src_mask, 72, 0)[0]
        model_txt = (
            " ".join(
                [vocabBertEng.get_itos()[x] for x in model_out if x != pad_idx]
            ).split(eos_string, 1)[0]
            + eos_string
        )
        print("Model Bert Output: " + model_txt.replace("\n", ""))
        print("========\n")
        ###
        # GPT MODEL
        ###
        rb = Batch(b[2], b[3], pad_idx) 
        src_tokens = [
            vocabGptDe.get_itos()[x] for x in rb.src[0] if x != pad_idx
        ]
        tgt_tokens = [
            vocabGptEng.get_itos()[x] for x in rb.tgt[0] if x != pad_idx
        ]
        print(
            "Source GPT Text (Input)        : "
            + " ".join(src_tokens).replace("\n", "")
        )
        print(
            "Target GPT Text (Ground Truth) : "
            + " ".join(tgt_tokens).replace("\n", "")
        )
        model_out = greedy_decode(modelGpt, rb.src, rb.src_mask, 72, 0)[0]
        model_txt = (
            " ".join(
                [vocabGptEng.get_itos()[x] for x in model_out if x != pad_idx]
            ).split(eos_string, 1)[0]
            + eos_string
        )
        print("Model Gpt Output: " + model_txt.replace("\n", ""))
        print("========\n")

def run_model_example(n_examples=25):
    global vocab_src, vocab_tgt, spacy_de, spacy_en

    print("Preparing Data ...")
    valid_dataloader = create_dataloaders(
        device,
        vocabBertDe,
        vocabBertEng,
        vocabGptDe,
        vocabGptEng,
        batch_size=1,
        max_padding = 72,
        is_distributed=False,
        tknzrBert=tknzrBert,
        tknzrGpt=tknzrGpt
    )
    #
    print("Comparing Model Outputs:")
    check_outputs(
        valid_dataloader, modelBert, vocabBertDe, vocabBertEng, modelGpt, vocabGptDe, vocabGptEng, 
        n_examples=n_examples
    )

run_model_example()
# Out:
# Preparing Data ...
# Comparing Model Outputs:
#
# Example 0 ========
#
# Source Bert Text (Input)        : <s> [CLS] Frauen gehen durch den Tie ##fs ##chn ##ee einen st ##eile ##n Ab ##hang hin ##unter . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Women walking through deep snow and down a steep hill . [SEP] </s>
# Model Bert Output: <s> [CLS] Women walking down the br ##ush ##ing down a steep slope . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> frau en ge hen dur ch den ti ef sch nee ein en ste il en ab hang hin un ter . </s>
# Target GPT Text (Ground Truth) : <s> women walking through deep snow and down a steep hill . </s>
# Model Gpt Output: <s> women walking down the deep snow on the top of a steep incline . </s>
# ========
#
#
# Example 1 ========
#
# Source Bert Text (Input)        : <s> [CLS] Eine Band spielt auf einer Frei ##licht ##b ##ühne am Fluss . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A band playing in an outdoor theater , along the river . [SEP] </s>
# Model Bert Output: <s> [CLS] A band plays on a stage , a stage by the river . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> eine band spi elt au f e iner fre ili ch t bu h ne am flu ss . </s>
# Target GPT Text (Ground Truth) : <s> a band playing in an outdoor theater , along the river . </s>
# Model Gpt Output: <s> a band is playing on an outdoor stage by the river . </s>
# ========
#
#
# Example 2 ========
#
# Source Bert Text (Input)        : <s> [CLS] Da sind viele Menschen in einem Gebäude und ein paar Menschen ko ##chen etwas zu esse ##n . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] There are many people in a building with some people cooking food . [SEP] </s>
# Model Bert Output: <s> [CLS] There is a lot of people cooking some food and some people cooking . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> da s ind vi ele men s chen in e ine m ge bau de und e in pa ar men s chen ko chen et was zu ess en . </s>
# Target GPT Text (Ground Truth) : <s> there are many people in a building with some people cooking food . </s>
# Model Gpt Output: <s> there are many people in a building and some people cooking in a building . </s>
# ========
#
#
# Example 3 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei Frauen bli ##cken auf viele Häuser hin ##ab . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two women look out at many houses below . [SEP] </s>
# Model Bert Output: <s> [CLS] Two women look down at many houses . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei frau en bli cken au f vi ele hau ser hin ab . </s>
# Target GPT Text (Ground Truth) : <s> two women look out at many houses below . </s>
# Model Gpt Output: <s> two women are looking down at many houses . </s>
# ========
#
#
# Example 4 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei Jungen innerhalb eines Za ##unes spring ##en in die Luft und halten dabei einen Basketball . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two boys inside a fe ##nce jump in the air while holding a basketball . [SEP] </s>
# Model Bert Output: <s> [CLS] Two boys jump in the air while holding a basketball in the air . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei jun gen inner hal b e ines za un es spring en in die lu ft und hal ten da be i ein en basketball . </s>
# Target GPT Text (Ground Truth) : <s> two boys inside a fence jump in the air while holding a basketball . </s>
# Model Gpt Output: <s> two young boys holding a ball in the air while holding a basketball . </s>
# ========
#
#
# Example 5 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei Frauen , eine aus Deutschland und eine aus China , treten bei einem Ring ##kampf auf einer Matt ##e gegen ##einander an . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] 2 females , 1 from german ##y and 1 from China , compete in a wrestling match on a mat . [SEP] </s>
# Model Bert Output: <s> [CLS] Two women , one of and a St ##itch is performing a wrestling on a mat . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei frau en , eine a us deu t sch land und eine a us china , tre ten be i e ine m ring ka mp f au f e iner mat te ge gene in ander an . </s>
# Target GPT Text (Ground Truth) : <s> 2 females , 1 from germany and 1 from china , compete in a wrestling match on a mat . </s>
# Model Gpt Output: <s> two women , one out of dirt and one in china are doing a match on a mat by a match . </s>
# ========
#
#
# Example 6 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein kleines Mädchen geht an einem kleinen Bach entlang [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A young girl walking along side a small creek [SEP] </s>
# Model Bert Output: <s> [CLS] A little girl walking along a small stream . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in kle ines mad chen ge h t an e ine m kle in en bach ent lang </s>
# Target GPT Text (Ground Truth) : <s> a young girl walking along side a small creek </s>
# Model Gpt Output: <s> a little girl walks along a small creek . </s>
# ========
#
#
# Example 7 ========
#
# Source Bert Text (Input)        : <s> [CLS] Eine l ##ä ##chel ##nde Frau mit einem p ##fir ##sic ##h ##far ##benen Träger ##shi ##rt hält ein Mountain ##bik ##e [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A sm ##iling woman in a pe ##ach tank top stands holding a mountain bike [SEP] </s>
# Model Bert Output: <s> [CLS] A sm ##iling woman with a pe ##ach and a shirt , holding a mountain bike . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> eine lac hel n de frau mit e ine m p fir si ch far ben en tra ger shirt halt e in mountain bike </s>
# Target GPT Text (Ground Truth) : <s> a smiling woman in a peach tank top stands holding a mountain bike </s>
# Model Gpt Output: <s> a smiling woman with a peach top is holding a mountain bike . </s>
# ========
#
#
# Example 8 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei Männer ring ##en auf einem gel ##b - blau ##en Boden . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two man are wrestling on a yellow and blue floor . [SEP] </s>
# Model Bert Output: <s> [CLS] Two men are wrestling on a yellow and blue floor . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei manner ring en au f e ine m gel b - b lau en bo den . </s>
# Target GPT Text (Ground Truth) : <s> two man are wrestling on a yellow and blue floor . </s>
# Model Gpt Output: <s> two men are wrestling on a yellow and blue floor . </s>
# ========
#
#
# Example 9 ========
#
# Source Bert Text (Input)        : <s> [CLS] Drei Männer auf P ##ferd ##en während eines Rennen ##s . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Three men on horses during a race . [SEP] </s>
# Model Bert Output: <s> [CLS] Three men on horses are during a race . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> dre i manner au f p fer den wah ren d e ines ren n ens . </s>
# Target GPT Text (Ground Truth) : <s> three men on horses during a race . </s>
# Model Gpt Output: <s> three men on horses during a race . </s>
# ========
#
#
# Example 10 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei wei ##bliche Teenage ##r halten eine Karte , auf der es um Punkte geht , und l ##ä ##chel ##n . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two teen ##age girls hold a card referring to periods as they sm ##ile . [SEP] </s>
# Model Bert Output: <s> [CLS] Two teen ##age females holding a map about to go down and sm ##iling . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei wei bli che teenager hal ten eine kar te , au f der es um pun k te ge h t , und lac hel n . </s>
# Target GPT Text (Ground Truth) : <s> two teenage girls hold a card referring to periods as they smile . </s>
# Model Gpt Output: <s> two teenage females are holding a map that is going up around and smiling . </s>
# ========
#
#
# Example 11 ========
#
# Source Bert Text (Input)        : <s> [CLS] Das Bild eines Jungen in einem gr ##ünen T - Shi ##rt , der auf einem Fa ##hr ##rad sit ##zt , sp ##iegel ##t sich in einer Sc ##hau ##fenster ##sche ##ibe . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A boy wearing a green shirt on a bi ##cycle reflect ##ing off a store window . [SEP] </s>
# Model Bert Output: <s> [CLS] Here is a picture of a boy in a green shirt sitting on a bi ##cycle in a store that has just reflect ##ion . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> das bi ld e ines jun gen in e ine m grun en t - shirt , der au f e ine m fa hr rad sit z t , sp ie g elt si ch in e iner sc hau fen ster sch ei be . </s>
# Target GPT Text (Ground Truth) : <s> a boy wearing a green shirt on a bicycle reflecting off a store window . </s>
# Model Gpt Output: <s> this picture of a boy in a green shirt sitting on a bicycle enjoys a window . </s>
# ========
#
#
# Example 12 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Mann mit einem gr ##ünen Shi ##rt k ##üs ##st ein wei ##nende ##s Klein ##kind und sieht dabei den L ##äufer ##n eines Straßen ##rennen ##s zu . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A man in a green shirt is kis ##sing a c ##ry ##ing to ##ddle ##r whilst watching runners in a road race . [SEP] </s>
# Model Bert Output: <s> [CLS] A man in a green shirt is kis ##sing a c ##ry ##ing infant while watching the race . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in mann mit e ine m grun en shirt ku s st e in we in en des kle in kind und sie h t da be i den lau fern e ines stra ß en ren n ens zu . </s>
# Target GPT Text (Ground Truth) : <s> a man in a green shirt is kissing a crying toddler whilst watching runners in a road race . </s>
# Model Gpt Output: <s> a man in a green shirt is kissing a small child as the lady of a race car along the road . </s>
# ========
#
#
# Example 13 ========
#
# Source Bert Text (Input)        : <s> [CLS] Eine Dame in einer le ##ucht ##end pink ##far ##benen Blu ##se zieht einen Wagen mit warm ##em Essen . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A lady in a bright pink shirt is pull ##ing a hot food car ##t . [SEP] </s>
# Model Bert Output: <s> [CLS] A lady in a bright pink bl ##ouse pull ##ing a car ##t with warm ##es . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> eine dame in e iner leu ch tend pink far ben en blu se z ie h t ein en wa gen mit war me m ess en . </s>
# Target GPT Text (Ground Truth) : <s> a lady in a bright pink shirt is pulling a hot food cart . </s>
# Model Gpt Output: <s> a lady in a bright pink shirt is pulling a cart with pink . </s>
# ========
#
#
# Example 14 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei junge Männer in Blue ##jean ##s und Turn ##sch ##uh ##en über ##quer ##en eine st ##ädtische Straße . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two young men in blue je ##ans and s ##nea ##kers cross an urban street . [SEP] </s>
# Model Bert Output: <s> [CLS] Two young men in blue je ##ans and s ##nea ##kers are crossing a city street . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei jun ge manner in blue jeans und turn schu hen u ber qu eren eine sta d ti sche stra ß e . </s>
# Target GPT Text (Ground Truth) : <s> two young men in blue jeans and sneakers cross an urban street . </s>
# Model Gpt Output: <s> two young men in blue jeans and sneakers cross a city street . </s>
# ========
#
#
# Example 15 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Hotel ##dien ##er in einem Man ##tel s ##chie ##bt eine La ##dung G ##ep ##äck . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A mot ##el valet man wearing a tren ##ch coat push ##ing a load of lu ##gga ##ge . [SEP] </s>
# Model Bert Output: <s> [CLS] A Lakers sous - man in a coat is push ##ing a load of lu ##gga ##ge . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in ho tel di ener in e ine m mantel schi e b t eine la dung ge pack . </s>
# Target GPT Text (Ground Truth) : <s> a motel valet man wearing a trench coat pushing a load of luggage . </s>
# Model Gpt Output: <s> a right in a coat pushing a load of luggage . </s>
# ========
#
#
# Example 16 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Mädchen in einem schwarzen Träger ##shi ##rt mit Cargo ##sh ##ort ##s scheint zu tan ##zen und ist dabei von mehreren anderen Menschen umgeben . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A girl in a black tank with cargo short ##s to what appears to be dancing with several people around . [SEP] </s>
# Model Bert Output: <s> [CLS] A girl in a black tank top and brief ##case ##s appears to be dancing and several other people . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in mad chen in e ine m schwar zen tra ger shirt mit car go shorts sche int zu tan zen und ist da be i von me h rer en ander en men s chen um ge ben . </s>
# Target GPT Text (Ground Truth) : <s> a girl in a black tank with cargo shorts to what appears to be dancing with several people around . </s>
# Model Gpt Output: <s> a girl in a black tank top is dressed as le gos and dancing from several other people . </s>
# ========
#
#
# Example 17 ========
#
# Source Bert Text (Input)        : <s> [CLS] Das So ##rti ##ment an Ban ##anen , Orange ##n , Melo ##nen usw . eines asi ##ati ##schen Ob ##st - und G ##em ##üs ##eh ##än ##dler ##s auf seinem kleinen Boot . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] An Asian fruit and veg ##eta ##ble vend ##or ' s selection of bana ##nas , orange ##s , me ##lons and more in his small boat . [SEP] </s>
# Model Bert Output: <s> [CLS] The ce ##ment from the ce ##ment , orange , tea , and veg ##eta ##bles , is order ##ing a small fruits and veg ##eta ##bles . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> das sor ti ment an ban an en , or ang en , mel on en us w . e ines a si atis chen ob st - und gem use handlers au f se ine m kle in en boot . </s>
# Target GPT Text (Ground Truth) : <s> an asian fruit and vegetable vendor ' s selection of bananas , oranges , mel ons and more in his small boat . </s>
# Model Gpt Output: <s> the benches are side by the benches , orange , and vegetable vendor is in his small , and vegetables on his boat . </s>
# ========
#
#
# Example 18 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Mann in einer über ##füllt ##en Bar l ##ä ##chel ##t mit einer Hand an seiner St ##irn . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A man is sm ##iling with one hand on his for ##eh ##ead at a crowd ##ed bar . [SEP] </s>
# Model Bert Output: <s> [CLS] A man sm ##iles as he holds his hand in a crowd ##ed bar . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in mann in e iner u ber full ten bar lac hel t mit e iner hand an se iner stir n . </s>
# Target GPT Text (Ground Truth) : <s> a man is smiling with one hand on his forehead at a crowded bar . </s>
# Model Gpt Output: <s> a man in a crowded bar smiles with a hand on his forehead . </s>
# ========
#
#
# Example 19 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei Männer in einem frem ##den Land l ##ä ##chel ##n , wobei einer von ihnen steht und einer mit über ##einander ##geschlagen ##en Bei ##nen sit ##zt . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two men in a foreign country sm ##iling , one standing and one sitting with his legs crossed . [SEP] </s>
# Model Bert Output: <s> [CLS] Two men in a foreign country sm ##iling while the one with a leg sitting and one with his legs crossed . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei manner in e ine m fre m den land lac hel n , wo be i e iner von i h nen ste h t und e iner mit u ber ein ander ge sch la gen en be in en sit z t . </s>
# Target GPT Text (Ground Truth) : <s> two men in a foreign country smiling , one standing and one sitting with his legs crossed . </s>
# Model Gpt Output: <s> two men in a foreign country smiling as they sit across one another sits with one step across the other . </s>
# ========
#
#
# Example 20 ========
#
# Source Bert Text (Input)        : <s> [CLS] Zwei junge Mädchen spielen Basketball , wobei die eine in Weiß einen Ko ##rb ##leger versucht und die andere in Rot verte ##idi ##gt . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] Two young girls playing basketball , one in white attempting a lay ##up while the other in red defend ##s . [SEP] </s>
# Model Bert Output: <s> [CLS] Two young girls playing basketball , one in white tries a basket while the other in red tries to ro ##pe . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> z wei jun ge mad chen spi elen basketball , wo be i die eine in wei ß ein en kor ble ger ver su cht und die and ere in rot verte idi gt . </s>
# Target GPT Text (Ground Truth) : <s> two young girls playing basketball , one in white attempting a lay up while the other in red defen ds . </s>
# Model Gpt Output: <s> two young girls are playing basketball , one in white one is making a conversation and the other in red , the red dun ks . </s>
# ========
#
#
# Example 21 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Mann im weißen He ##md macht Sc ##has ##ch ##lik . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A man in a white shirt is making shi ##sh ka ##bo ##b . [SEP] </s>
# Model Bert Output: <s> [CLS] A man in a white shirt is making a catch ##ing object . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in mann im wei ß en hem d mach t scha sch lik . </s>
# Target GPT Text (Ground Truth) : <s> a man in a white shirt is making shi sh k abo b . </s>
# Model Gpt Output: <s> a man in a white shirt is making sheep . </s>
# ========
#
#
# Example 22 ========
#
# Source Bert Text (Input)        : <s> [CLS] Eine junge Frau mit bra ##une ##m Haar und Träger ##shi ##rt nimmt mit einer Kamera ein Foto auf . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A young woman with brown hair and tank top is taking a picture with a camera . [SEP] </s>
# Model Bert Output: <s> [CLS] A young woman with brown hair and tank top taking a picture with a camera . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> eine jun ge frau mit bra une m ha ar und tra ger shirt ni mm t mit e iner ka mera e in fo to au f . </s>
# Target GPT Text (Ground Truth) : <s> a young woman with brown hair and tank top is taking a picture with a camera . </s>
# Model Gpt Output: <s> a young woman with brown hair and wearing a t - shirt is taking a picture with a camera . </s>
# ========
#
#
# Example 23 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Mann war ##tet am Bahn ##ste ##ig auf den Zug . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A male is waiting for the train to arrive at the platform . [SEP] </s>
# Model Bert Output: <s> [CLS] A man wait ##s at the platform for the train . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in mann war tet am bah n ste ig au f den zu g . </s>
# Target GPT Text (Ground Truth) : <s> a male is waiting for the train to arrive at the platform . </s>
# Model Gpt Output: <s> a man waits for the train to train at the train station . </s>
# ========
#
#
# Example 24 ========
#
# Source Bert Text (Input)        : <s> [CLS] Ein Typ renn ##t vor einem schwarzen Bull ##en davon . [SEP] </s>
# Target Bert Text (Ground Truth) : <s> [CLS] A gu ##y is running away from a black bu ##ll . [SEP] </s>
# Model Bert Output: <s> [CLS] A gu ##y running away in front of a black bu ##ll . [SEP] </s>
# ========
#
# Source GPT Text (Input)        : <s> e in ty p ren nt vor e ine m schwar zen bul len da von . </s>
# Target GPT Text (Ground Truth) : <s> a guy is running away from a black bull . </s>
# Model Gpt Output: <s> a guy is running away from a black bull . </s>
# ========
